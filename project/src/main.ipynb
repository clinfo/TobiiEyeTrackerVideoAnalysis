# %%
import glob
import re
import os
import time
import pandas as pd
import cv2
import math
import numpy as np
import scene
from os.path import expanduser

# %%
#Get scenes
scene, start = scene.makeScene()

# %%
#Get homefilepath
home = expanduser("~")

# %%
path1 = home + '/Documents/EyeTrackerAnalysis/'
path2 = home + '/Downloads/data_video/use/'
path3 = path0 + 'output_csv/'

# %% [markdown]
# # Original Distance score

# %%
#moving objects' data
OriginalOutputFilepath = home + '/Documents/EyeTrackerAnalysis/output.csv'
OriginalOutput = pd.read_csv(OriginalOutputFilepath)
x = []
y = []
for z in range(int(start[-1]*20.02002)):
    c = z//20.02002
    c = int(c)
    x.append(output.loc[c, 'X(pixel)'])
    y.append(output.loc[c, 'Y(pixel)'])

path0 = home + '/Documents/EyeTrackerAnalysis/'
df_output = pd.DataFrame({'output_x': x, 'output_y': y})
df_output.to_csv(path0 + 'Output/MovingObjects.csv', index=False)

# %%
def AddDistancescore(pathA, pathB): 
    
    #video_Recording*.tsv: Eye-gaze position data for each individual obtained from the eye-tracker
    for filepath in glob.glob(pathA + 'video_Recording*.tsv'):    
        if __name__ == '__main__':
            starttime = time.time()
        df = pd.read_csv(filepath, sep='\t')
        df = df.fillna('NaN')
        df = df.rename(columns={'Recording timestamp':'Recording_timestamp'})
        df_s = df.copy().loc[:int(start[-1]*20.02002)-1, :]
        df_s[['Gaze point X', 'Gaze point Y']] = df_s[['Gaze point X', 'Gaze point Y']].astype(float)
        x = re.sub("\\D", "", filepath)
        
        df_gaze_x = np.array(df_s[('Gaze point X')])
        df_gaze_y = np.array(df_s[('Gaze point Y')])
        output_x = np.array(df_output['output_x'])
        output_y = np.array(df_output['output_y'])
        df_s['timestamp_0'] = np.array(df_s['Recording_timestamp'])-df_s.loc[0, 'Recording_timestamp']
        df_s['x'] = (df_gaze_x-150)/2.25
        df_s['y'] = df_gaze_y/2.25
        df_s['distance'] = np.sqrt((output_x-(df_gaze_x-150)/2.25)**2+(output_y-df_gaze_y/2.25)**2)
        
        os.makedirs(pathB, exist_ok=True)
        df_s.to_csv(pathB + 'm_video_Recording{}.csv'.format(x))
        
        elapsed_time = time.time() - starttime
        print(x, 'Done', "elapsed_time:{0}".format(elapsed_time) + "[sec]")

# %%
AddDistancescore(path2+'use/', path3+'personal_data/')
# Out:
# 115 Done elapsed_time:0.3721129894256592[sec]
# 129 Done elapsed_time:0.3792150020599365[sec]
# 4 Done elapsed_time:0.37033987045288086[sec]
# 5 Done elapsed_time:0.3995640277862549[sec]
# 16 Done elapsed_time:0.414370059967041[sec]
# 128 Done elapsed_time:0.33312368392944336[sec]
# 114 Done elapsed_time:0.3990061283111572[sec]
# 102 Done elapsed_time:0.3385121822357178[sec]
# 116 Done elapsed_time:0.4377460479736328[sec]
# 14 Done elapsed_time:0.440967321395874[sec]
# 29 Done elapsed_time:0.39614009857177734[sec]
# 117 Done elapsed_time:0.37931394577026367[sec]
# 103 Done elapsed_time:0.4326012134552002[sec]
# 107 Done elapsed_time:0.38497304916381836[sec]
# 11 Done elapsed_time:0.4329650402069092[sec]
# 38 Done elapsed_time:0.4276618957519531[sec]
# 106 Done elapsed_time:0.3519890308380127[sec]
# 138 Done elapsed_time:0.36168408393859863[sec]
# 110 Done elapsed_time:0.33618807792663574[sec]
# 104 Done elapsed_time:0.43700194358825684[sec]
# 1 Done elapsed_time:0.45666003227233887[sec]
# 139 Done elapsed_time:0.44269227981567383[sec]
# 74 Done elapsed_time:0.33603572845458984[sec]
# 48 Done elapsed_time:0.4111747741699219[sec]
# 49 Done elapsed_time:0.43095970153808594[sec]
# 75 Done elapsed_time:0.3524951934814453[sec]
# 61 Done elapsed_time:0.41799402236938477[sec]
# 163 Done elapsed_time:0.36569666862487793[sec]
# 161 Done elapsed_time:0.38295793533325195[sec]
# 149 Done elapsed_time:0.3331282138824463[sec]
# 77 Done elapsed_time:0.3766648769378662[sec]
# 88 Done elapsed_time:0.41405415534973145[sec]
# 89 Done elapsed_time:0.4338212013244629[sec]
# 62 Done elapsed_time:0.37641406059265137[sec]
# 76 Done elapsed_time:0.42057013511657715[sec]
# 148 Done elapsed_time:0.35335612297058105[sec]
# 160 Done elapsed_time:0.4520401954650879[sec]
# 158 Done elapsed_time:0.33724308013916016[sec]
# 164 Done elapsed_time:0.43508005142211914[sec]
# 72 Done elapsed_time:0.3835330009460449[sec]
# 67 Done elapsed_time:0.44295716285705566[sec]
# 73 Done elapsed_time:0.36308789253234863[sec]
# 165 Done elapsed_time:0.35437607765197754[sec]
# 159 Done elapsed_time:0.40802693367004395[sec]
# 167 Done elapsed_time:0.3908510208129883[sec]
# 59 Done elapsed_time:0.3817291259765625[sec]
# 65 Done elapsed_time:0.3759920597076416[sec]
# 70 Done elapsed_time:0.3369870185852051[sec]
# 166 Done elapsed_time:0.4181487560272217[sec]
# 143 Done elapsed_time:0.36798691749572754[sec]
# 69 Done elapsed_time:0.3599076271057129[sec]
# 82 Done elapsed_time:0.4247019290924072[sec]
# 83 Done elapsed_time:0.42711710929870605[sec]
# 68 Done elapsed_time:0.4344780445098877[sec]
# 142 Done elapsed_time:0.4000251293182373[sec]
# 156 Done elapsed_time:0.34629297256469727[sec]
# 140 Done elapsed_time:0.49541592597961426[sec]
# 154 Done elapsed_time:0.3796727657318115[sec]
# 56 Done elapsed_time:0.44181299209594727[sec]
# 95 Done elapsed_time:0.4297220706939697[sec]
# 81 Done elapsed_time:0.4813361167907715[sec]
# 80 Done elapsed_time:0.4263019561767578[sec]
# 94 Done elapsed_time:0.3777179718017578[sec]
# 43 Done elapsed_time:0.44085192680358887[sec]
# 57 Done elapsed_time:0.443817138671875[sec]
# 155 Done elapsed_time:0.41839599609375[sec]
# 141 Done elapsed_time:0.4366912841796875[sec]
# 90 Done elapsed_time:0.43039679527282715[sec]
# 84 Done elapsed_time:0.4339120388031006[sec]
# 85 Done elapsed_time:0.4318718910217285[sec]
# 46 Done elapsed_time:0.4293200969696045[sec]
# 150 Done elapsed_time:0.38898611068725586[sec]
# 144 Done elapsed_time:0.3594679832458496[sec]
# 152 Done elapsed_time:0.42925071716308594[sec]
# 146 Done elapsed_time:0.3712310791015625[sec]
# 78 Done elapsed_time:0.41062307357788086[sec]
# 44 Done elapsed_time:0.4213569164276123[sec]
# 50 Done elapsed_time:0.44749879837036133[sec]
# 87 Done elapsed_time:0.4476017951965332[sec]
# 51 Done elapsed_time:0.4340207576751709[sec]
# 45 Done elapsed_time:0.4441719055175781[sec]
# 79 Done elapsed_time:0.4374558925628662[sec]
# 147 Done elapsed_time:0.3456728458404541[sec]
# 153 Done elapsed_time:0.3569929599761963[sec]
# 134 Done elapsed_time:0.4198029041290283[sec]
# 108 Done elapsed_time:0.43451523780822754[sec]
# 37 Done elapsed_time:0.4296882152557373[sec]
# 123 Done elapsed_time:0.3768727779388428[sec]
# 137 Done elapsed_time:0.4285738468170166[sec]
# 20 Done elapsed_time:0.4197356700897217[sec]
# 136 Done elapsed_time:0.3361527919769287[sec]
# 126 Done elapsed_time:0.43220973014831543[sec]
# 18 Done elapsed_time:0.3791959285736084[sec]
# 25 Done elapsed_time:0.4251260757446289[sec]
# 133 Done elapsed_time:0.4389657974243164[sec]
# 119 Done elapsed_time:0.4109761714935303[sec]
# 27 Done elapsed_time:0.41887497901916504[sec]
# 33 Done elapsed_time:0.44519901275634766[sec]
# 9 Done elapsed_time:0.3271479606628418[sec]
# 32 Done elapsed_time:0.40093111991882324[sec]
# 26 Done elapsed_time:0.4105079174041748[sec]
# 124 Done elapsed_time:0.3223099708557129[sec]
# 130 Done elapsed_time:0.3499879837036133[sec]
# 118 Done elapsed_time:0.3287031650543213[sec]

# %% [markdown]
# # Original Saliency scores

# %%
def AddSaliencyscores(gfilepath, filepathFG, filepathSR, filepathMS):
    for filepath in glob.glob(gfilepath +'m_video_Recording*.csv'):  
        if __name__ == '__main__':
            starttime = time.time()

            df = pd.read_csv(filepath, sep=',', index_col=0)
            df = df.fillna('NaN')
            x = re.sub("\\D", "", filepath)
            df['FG_{}'.format(x)] = ''
            df['SR_{}'.format(x)] = ''
            df['Mo_{}'.format(x)] = ''
    
            for a in range(int(start[-1]*20.02002)):
                b = a//20.02002
                image_fileFG = filepathFG +'FG_img_{}.png'.format(str(int(b)).zfill(6))
                image_fileSR = filepathSR + 'SR_img_{}.png'.format(str(int(b)).zfill(6))
                image_fileMS = filepathMo + 'Mo_img_{}.png'.format(str(int(b)).zfill(6))
                
                imgFG = cv2.imread(image_fileFG)
                imgSR = cv2.imread(image_fileSR)
                imgMS = cv2.imread(image_fileMS)
                
                if not((df.loc[a, ('x')]=='NaN') or (df.loc[a, ('y')]=='NaN')):
                    if 0<=(int(df.loc[a, ('x')]))<=719 and 0<=(int(df.loc[a, ('y')]))<=479:
                        df.loc[a, ('FG_{}'.format(x))] = (imgFG[int(df.loc[a, ('y')]),int(df.loc[a, ('x')])])[0]/255
                        df.loc[a, ('SR_{}'.format(x))] = (imgSR[int(df.loc[a, ('y')]),int(df.loc[a, ('x')])])[0]/255
                        df.loc[a, ('Mo_{}'.format(x))] = (imgMS[int(df.loc[a, ('y')]),int(df.loc[a, ('x')])])[0]/255
                    else:
                        df.loc[a, ('FG_{}'.format(x))] = 0
                        df.loc[a, ('SR_{}'.format(x))] = 0
                        df.loc[a, ('Mo_{}'.format(x))] = 0
                else:
                    df.loc[a, ('FG_{}'.format(x))] = 'NaN'
                    df.loc[a, ('SR_{}'.format(x))] = 'NaN'
                    df.loc[a, ('Mo_{}'.format(x))] = 'NaN'
                    
            df.to_csv(gfilepath + 'm_video_Recording{}.csv'.format(x))
            elapsed_time = time.time() - starttime
            print(x, 'Done', "elapsed_time:{0}".format(elapsed_time) + "[sec]")

# %%
AddSaliencyscores(
path3 + 'personal_data/',
path1 + 'saliency_map/FG/',
path1 + 'saliency_map/SR/',
path1 + 'saliency_map/Mo/')
# Out:
# 31271
# 5 Done elapsed_time:391.6315462589264[sec]
# 31271
# 166 Done elapsed_time:397.0046811103821[sec]
# 31271
# 56 Done elapsed_time:437.92548179626465[sec]
# 31271
# 95 Done elapsed_time:422.63500595092773[sec]
# 31271
# 81 Done elapsed_time:408.32652401924133[sec]
# 31271
# 80 Done elapsed_time:403.2654848098755[sec]
# 31271
# 94 Done elapsed_time:376.67100405693054[sec]
# 31271
# 43 Done elapsed_time:396.75018310546875[sec]
# 31271
# 57 Done elapsed_time:425.74566197395325[sec]
# 31271
# 167 Done elapsed_time:401.64919996261597[sec]
# 31271
# 4 Done elapsed_time:413.6494379043579[sec]
# 31271
# 159 Done elapsed_time:433.27227425575256[sec]
# 31271
# 165 Done elapsed_time:519.9376249313354[sec]
# 31271
# 69 Done elapsed_time:416.95405888557434[sec]
# 31271
# 82 Done elapsed_time:401.74416184425354[sec]
# 31271
# 83 Done elapsed_time:414.0973837375641[sec]
# 31271
# 68 Done elapsed_time:17019.858976125717[sec]
# 31271
# 164 Done elapsed_time:408.9527449607849[sec]
# 31271
# 158 Done elapsed_time:374.56289196014404[sec]
# 31271
# 160 Done elapsed_time:394.0253040790558[sec]
# 31271
# 148 Done elapsed_time:364.48771119117737[sec]
# 31271
# 44 Done elapsed_time:369.051167011261[sec]
# 31271
# 50 Done elapsed_time:385.28735518455505[sec]
# 31271
# 78 Done elapsed_time:360.1270089149475[sec]
# 31271
# 87 Done elapsed_time:376.04488492012024[sec]
# 31271
# 79 Done elapsed_time:349.7594027519226[sec]
# 31271
# 51 Done elapsed_time:357.05858302116394[sec]
# 31271
# 45 Done elapsed_time:345.53578066825867[sec]
# 31271
# 149 Done elapsed_time:332.80619406700134[sec]
# 31271
# 161 Done elapsed_time:345.6463370323181[sec]
# 31271
# 163 Done elapsed_time:333.17225217819214[sec]
# 31271
# 90 Done elapsed_time:363.6710901260376[sec]
# 31271
# 84 Done elapsed_time:348.43768787384033[sec]
# 31271
# 85 Done elapsed_time:344.7860908508301[sec]
# 31271
# 46 Done elapsed_time:345.99706506729126[sec]
# 31271
# 1 Done elapsed_time:354.90349292755127[sec]
# 31271
# 139 Done elapsed_time:349.08507800102234[sec]
# 31271
# 20 Done elapsed_time:377.97140312194824[sec]
# 31271
# 110 Done elapsed_time:332.102313041687[sec]
# 31271
# 104 Done elapsed_time:363.04383611679077[sec]
# 31271
# 138 Done elapsed_time:332.7878611087799[sec]
# 31271
# 106 Done elapsed_time:328.4768419265747[sec]
# 31271
# 37 Done elapsed_time:346.56561613082886[sec]
# 31271
# 107 Done elapsed_time:336.7155599594116[sec]
# 31271
# 117 Done elapsed_time:335.3586769104004[sec]
# 31271
# 103 Done elapsed_time:375.6147701740265[sec]
# 31271
# 27 Done elapsed_time:335.88701605796814[sec]
# 31271
# 33 Done elapsed_time:364.9830458164215[sec]
# 31271
# 32 Done elapsed_time:347.06886410713196[sec]
# 31271
# 26 Done elapsed_time:361.8115119934082[sec]
# 31271
# 102 Done elapsed_time:329.95871686935425[sec]
# 31271
# 116 Done elapsed_time:359.9138059616089[sec]
# 31271
# 114 Done elapsed_time:354.4728829860687[sec]
# 31271
# 128 Done elapsed_time:336.2807619571686[sec]
# 31271
# 18 Done elapsed_time:333.5777759552002[sec]
# 31271
# 25 Done elapsed_time:360.2577269077301[sec]
# 31271
# 129 Done elapsed_time:330.6119577884674[sec]
# 31271
# 115 Done elapsed_time:328.03886890411377[sec]
# 31271
# 118 Done elapsed_time:324.9791450500488[sec]
# 31271
# 124 Done elapsed_time:349.82210993766785[sec]
# 31271
# 130 Done elapsed_time:331.58765506744385[sec]
# 31271
# 14 Done elapsed_time:348.80744099617004[sec]
# 31271
# 29 Done elapsed_time:361.7886230945587[sec]
# 31271
# 119 Done elapsed_time:357.580176115036[sec]
# 31271
# 133 Done elapsed_time:370.02832412719727[sec]
# 31271
# 16 Done elapsed_time:364.10515308380127[sec]
# 31271
# 126 Done elapsed_time:345.2600612640381[sec]
# 31271
# 136 Done elapsed_time:349.56433176994324[sec]
# 31271
# 123 Done elapsed_time:330.73001885414124[sec]
# 31271
# 137 Done elapsed_time:346.34691309928894[sec]
# 31271
# 11 Done elapsed_time:346.63645911216736[sec]
# 31271
# 38 Done elapsed_time:348.96416997909546[sec]
# 31271
# 108 Done elapsed_time:380.9218897819519[sec]
# 31271
# 134 Done elapsed_time:332.42653489112854[sec]
# 31271
# 147 Done elapsed_time:336.5876998901367[sec]
# 31271
# 153 Done elapsed_time:334.52511286735535[sec]
# 31271
# 77 Done elapsed_time:334.3755609989166[sec]
# 31271
# 88 Done elapsed_time:342.49831080436707[sec]
# 31271
# 89 Done elapsed_time:340.8697519302368[sec]
# 31271
# 62 Done elapsed_time:332.65243220329285[sec]
# 31271
# 76 Done elapsed_time:365.8363027572632[sec]
# 31271
# 152 Done elapsed_time:345.58134508132935[sec]
# 31271
# 146 Done elapsed_time:347.6158401966095[sec]
# 31271
# 150 Done elapsed_time:328.91406297683716[sec]
# 31271
# 144 Done elapsed_time:328.84693813323975[sec]
# 31271
# 48 Done elapsed_time:346.77034997940063[sec]
# 31271
# 74 Done elapsed_time:330.0118730068207[sec]
# 31271
# 75 Done elapsed_time:342.6373770236969[sec]
# 31271
# 61 Done elapsed_time:342.84539222717285[sec]
# 31271
# 49 Done elapsed_time:365.9660601615906[sec]
# 31271
# 155 Done elapsed_time:362.7627589702606[sec]
# 31271
# 141 Done elapsed_time:377.3573098182678[sec]
# 31271
# 65 Done elapsed_time:331.0128152370453[sec]
# 31271
# 59 Done elapsed_time:345.8668370246887[sec]
# 31271
# 70 Done elapsed_time:348.0341999530792[sec]
# 31271
# 140 Done elapsed_time:344.03508400917053[sec]
# 31271
# 154 Done elapsed_time:330.63804292678833[sec]
# 31271
# 9 Done elapsed_time:341.478129863739[sec]
# 31271
# 142 Done elapsed_time:338.5384669303894[sec]
# 31271
# 156 Done elapsed_time:359.9803309440613[sec]
# 31271
# 72 Done elapsed_time:376.23583006858826[sec]
# 31271
# 67 Done elapsed_time:407.9323630332947[sec]
# 31271
# 73 Done elapsed_time:392.08994913101196[sec]
# 31271
# 143 Done elapsed_time:393.1312892436981[sec]

# %% [markdown]
# # Scores for the statistical analysis

# %%
ID = []
distanceos_med = []
FGos_med = []
SRos_med = []
MSos_med = []

for filepath in glob.glob(output_dir + '/output_csv/personal_data/m_video_Recording*.csv'): 
    df = pd.read_csv(filepath, sep=',', index_col=0)
    df_gaze = df.query('x <= 720 & 0 <= x & y <= 480 & 0 <=y' )
    df_gazedes = df_gaze.describe()
    
    num = re.sub("\\D", "", filepath)
    ID.append(num)
    
    distanceos_med.append(df_gazedes.loc['50%', 'distance'])
    FGos_med.append(df_gazedes.loc['50%', 'FG_{}'.format(num)])
    SRos_med.append(df_gazedes.loc['50%', 'SR_{}'.format(num)])
    MSos_med.append(df_gazedes.loc['50%', 'MS_{}'.format(num)])

# %%
df_scores　= pd.DataFrame({ 'ID' : ID,
                            'distanceos_median': distanceos_med,
                            'FGos_median': FGos_med,
                            'SRos_median': SRos_med,
                            'MSos_median': MSos_med
                          })
df_scores.to_csv(home + '/output_csv/output_scores.csv', index=False)
